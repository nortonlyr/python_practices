# %%
from bs4 import BeautifulSoup
from urllib import request

url = 'https://pythonf.cn'
headers = {
    
}
req = request.Request(url, headers=headers)
response = request.urlopen(req)
content = response.read()
soup = BeautifulSoup(content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-CN">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- 最新版本的 Bootstrap 核心 CSS 文件 -->
# <link href="/public/static/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- 可选的 Bootstrap 主题文件（一般不用引入） -->
# <link href="/public/static/css/bootstrap-theme.min.css" rel="stylesheet"/>
# <link href="/public/static/css/reset.css" rel="stylesheet"/>
# <!-- 检测顶端active标签 -->
# <script src="/public/static/js/jquery.js" type="text/javascript"></script>
# <script src="/public/static/js/qiehuanbiaoqian.js" type="text/javascript"></script>
# <!-- 最新的 Bootstrap 核心 JavaScript 文件 -->
# <script src="/public/static/js/bootstrap.min.js" type="text/javascript"></script>
# <title>PythonFree-Python教程</title>
# <meta content="Python,Python教程,Python官方文档,Pycharm激活,网络爬虫,selenium,BeautifulSoup,人工智能,数据分析,Pandas,Pillow" name="keywords">
# <meta content="PythonFree分享海量Python教程，关注最新Python热点技术。专注web爬虫、AI人工智能、数据分析方面的实际应用。介绍selenium,BeautifulSoup,Pyppeteer,NumPy,Pandas,Pillow等常用库的使用教程" name="description">
# <script>
#         var _hmt = _hmt || [];
#         (function() {
#           var hm = document.createElement("script");
#           hm.src = "https://hm.baidu.com/hm.js?83d0b33b94edae1df3ba08b798d44627";
#           var s = document.getElementsByTagName("script")[0];
#           s.parentNode.insertBefore(hm, s);
#         })();
#         </script>
# <script>
#         $(function () {
#             $(".dropdown").mouseover(function () {
#                 $(this).addClass("open");
#             });
#
#             $(".dropdown").mouseleave(function(){
#                 $(this).removeClass("open");
#             })
#
#         })
#         </script>
# </meta></meta></head>
# <body style="margin:0 auto;max-width:1280px;padding: 50px 5px 5px 5px; ">
# <nav class="navbar navbar-default navbar-fixed-top">
# <div class="container-fluid" style="margin:0 auto;max-width:1280px;">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="https://www.pythonf.cn" style="font-weight:bold;">Python Free</a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">Python教程<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/category1">Python/Pycharm安装和激活</a></li>
# <li><a href="/category2">Python基础教程</a></li>
# <li><a href="/category3">Python基础教程2</a></li>
# <li><a href="/category4">正则表达式</a></li></ul></li></ul></div></div></nav></body></html>
# <li><a href="/category8">Python官方中文文档</a></li>
# <li><a href="/category5">Python其他教程</a></li>
# <li><a href="/category6">Python精选</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/daohang1">查看全部</a></li>
#
#
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">网络爬虫<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/category21">自动化|Selenium教程</a></li>
# <li><a href="/category22">BeautifulSoup教程</a></li>
# <li><a href="/category23">Pyppeteer教程</a></li>
# <li><a href="/category24">Airtest教程</a></li>
# <li><a href="/category25">正文通用抽取器</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/daohang2">查看全部</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">人工智能<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/category34">TensorFlow教程</a></li>
# <li><a href="/category31">微信控制|itchat教程</a></li>
# <li><a href="/category32">图像处理|Pillow教程</a></li>
# <li><a href="/category33">深度学习|NumPy教程</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/daohang3">查看全部</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">数据分析<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/category41">Pandas教程</a></li>
# <li><a href="/category42">NumPy教程</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/daohang4">查看全部</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">Python Web<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/category53">Python服务端部署教程</a></li></ul></li>
# <li><a href="/category52">Flask教程</a></li>
# <li><a href="/category7">Sanic教程</a></li>
# <li><a href="/category51">FastApi教程</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/daohang6">查看全部</a></li>
#
#
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" role="button" style="font-weight:bold;">其他教程<span class="caret"></span></a>
# <ul class="dropdown-menu" style="min-width:100%;">
# <li><a href="/daohang5">查看全部</a></li>
# </ul>
# </li>
#
# <!--               <form class="navbar-form navbar-right" action="/sousuo" method="get">
#                 <div class="form-group">
#                     <input type="text" class="form-control" id='key' name='key' placeholder="请输入关键词" value=''>
#                 </div>
#                 <button type="submit" class="btn btn-default">搜索</button>
#               </form>
#  --> <!-- /.navbar-collapse -->
# <!-- /.container-fluid -->
#
# <div class="container-fluid" id="neirong" style="padding:1em;">
# <div class="row">
# <div class="col-sm-12" style="padding: 2px">
# <img alt="微配音" class="" height="" src="https://www.ls27.cn/public/banner/wpybanner-web.png" width="100%"/>
# <a class="text-center list-group-item active" style="font-weight:bold ">
#    最新文章
#   </a>
# <ul class="list-group">
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149598" style="color: #4f4a48;word-break: break-all">图像的腐蚀和膨胀,erosion,dilation</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">其实就是定义一个连通规则(structure)，用该连通区域在图像上stride, 用连通区域内的最小或者最大值代替原来的值。(边界上只覆盖部分值)。腐蚀和膨胀的一个作用是提取二值图像的边界。腐蚀一般用来提取内边界，内边界由边界点构成，是区域的一部分。内边界的提取利用图像的腐蚀处理得到原图像的一个收缩，再将收缩结果与目标图像进行异或运算，实现差值部分的提取。...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149597" style="color: #4f4a48;word-break: break-all">Python模块随机,random</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">Python-模块-randomrandom模块的定义random模块的常见方法random模块实例random模块的定义random用于生成随机数、随机字符串。random模块的常见方法方法解释random()生成 0 到 1 之间的随机浮点数randint(1,9)生成 1 到 9 之间的随机整数uniform(1,9)生成 1 到 9 之间的随机浮点数...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149596" style="color: #4f4a48;word-break: break-all">01和02，数组中的重复数,剑,指,offer0102</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">数组中的重复数题目要求是输入一个长度为n的数组，含有1至n-1的整数，找出其中的重复数，如果对python熟悉的话，首先就会想到一个重要的函数sorted:sorted(data,cmp=None,key=None,reverse=False)其中，data是待排序数据，可以使List或者iterator, cmp和key都是函数，这两个函数作用与data的...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149595" style="color: #4f4a48;word-break: break-all">张量流图像的记录识别,TensorflowMNIST,原始,图片,TFRecord,方式,4,取多张,手写,数字,进行,测试</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">Tensorflow MNIST原始图片TFRecord方式识别---4. 取多张手写数字图片进行测试1. 测试图片数据预处理2. 测试已训练模型准确率本章节是《Tensorflow MNIST原始图片TFRecord方式识别》的最后一节，验证模型，测试模型识别准确率。1. 测试图片数据预处理验证训练模型的准确率，首先需要将测试图片作预处理，转为像素矩阵。测...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149594" style="color: #4f4a48;word-break: break-all">当Seaborn绘制一个热图时，Y轴的顶部和底部线将小于一半。如何解决这个问题,seaborn,画热,力图,y,最,上面,下面,一行,会少,请问,该</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">代码生成的原始热力图，其他地方的小方格都是正方形，但是第一行和最后一行都缺一半的方格，当出现标签名时更为明显。原因是:这是matplotlib库3.1.0—3.1.1版本出现的bug，解决方案如下：回退到低版本pip install matplotlib==3.0.3升级到3.1.2及以上的版本如果不想升级.那就记得手工调整def Thermodynamic...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149593" style="color: #4f4a48;word-break: break-all">Python图像识别,图片</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">本文不介绍那么多，直接上内容一、需要下载的文件：tesseract-orcpip install pytesseract # python与tesseract-orc之间的关联语言包：简体中文包，繁体中文包将上面下载到的东西进行安装即可二、环境配置：tesseract-orc下载完毕之后傻瓜式安装即可但是一定记住安装的路径，等下需要配置系统环境变量增加一个T...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149592" style="color: #4f4a48;word-break: break-all">私有爬虫红网爬行图片,私人,取</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">工作流程1 首先需要在一个爬虫中，获取到图片的url并存储起来。也是就是我们项目中test_spider.py中testSpider类的功能2 项目从爬虫返回，进入到项目通道也就是pipelines中3 在通道中，在第一步中获取到的图片url将被scrapy的调度器和下载器安排下载。4 下载完成后，将返回一组列表，包括下载路径，源抓取地址和图片的校验码大致的...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149591" style="color: #4f4a48;word-break: break-all">机器学习简介，Python机器学习基础教程（好书分享更新）,入门,书以,语言,介绍,中</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">内容简介基于Python3的机器学习入门教程 以机器学习算法实践为重点 使用scikit-learn库从头构建机器学习应用 涵盖模型评估调参方法 交差验证网格搜索 管道概念及文本数据处理方法等内容作者简介  · · · · · ·Andreas C.Müller，scikit-learn库维护者和核心贡献者。现任哥伦比亚大学数据科学研究院讲师，曾任纽约大学数...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149590" style="color: #4f4a48;word-break: break-all">CNNs+bilstm代码学习,CNNSBiLSTM</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">nn.pydeftag_dataset(dataset):correctLabels=[]#标注的序列predLabels=[]#预测的序列b=Progbar(len(dataset))#Progbar是进度条fori,datainenumerate(dataset):#enumerate() 函数用于将一个可遍历的数据对象(dataset)组合为一个索引序...</p>
# </li>
# <li class="list-group-item">
# <h1 class="media-heading" style="font-size:1.1em;font-weight:bold;">
# <a href="/read/149589" style="color: #4f4a48;word-break: break-all">两个数之和,Leetcode,千题,968,两数</a>
# </h1>
# <p style=""><span class="label label-success">python</span><span class="" style="color: #999999"> 发表时间：2020-09-29</span></p>
# <p class="hidden-xs hidden-sm" style="font-size:1em">给定一个二叉树，我们在树的节点上安装摄像头。节点上的每个摄影头都可以监视其父对象、自身及其直接子对象。计算监控树的所有节点所需的最小摄像头数量。思路首先要表示节点的状态flag：没有被覆盖：0，被覆盖：1，装了摄像头：2。可以用递归的形式，也可以根据贪心，看两个字节点的情况。classSolution:defminCameraCover(self,root:...</p>
# </li>
# <ul class="pager"><li class="disabled"><span>« 上一页</span></li> <li><a href="/?page=2">下一页 »</a></li></ul> </ul>
# </div>
# </div>
# </div>
# <hr style="width:100%;height:5px;background-color:#696969;"/>
# <div class="row" id="yejiao" style="padding:10px 0 10px 0">
# <div class="col-sm-4">
# <p>
# <b>Python Free</b>
# <br/><br/>邮箱：417803890@qq.com
#             <br/>QQ：417803890
#             <br/><br/><a href="http://www.beian.miit.gov.cn/">皖ICP备19001818号</a>
# <br/>© 2019 copyright <a href="https://www.pythonf.cn/">www.pythonf.cn</a> - All rights reserved
#             </p>
# </div>
# <div class="col-sm-4 text-center" style="color: green">
# <p>微信扫一扫关注公众号：</p>
# <img alt="联系方式" src="/public/photo/gongzhonghao.jpg" style="width: 86px"/>
# <p>Python Free</p>
# </div>
# <div class="col-sm-4">
# <p>
# <b>友情链接</b>
# <br/><br/><a href="https://www.ls27.cn/">科技口袋</a>
# <br/>网站地图：
#             <br/><a href="https://www.pythonf.cn/public/sitemap/sitemap1.xml">1</a><a href="https://www.pythonf.cn/public/sitemap/sitemap2.xml">2</a><a href="https://www.pythonf.cn/public/sitemap/sitemap3.xml">3</a><a href="https://www.pythonf.cn/public/sitemap/sitemap4.xml">4</a>
# <br/><a href="https://www.pythonf.cn/public/sitemap/sitemap5.xml">5</a><a href="https://www.pythonf.cn/public/sitemap/sitemap6.xml">6</a><a href="https://www.pythonf.cn/public/sitemap/sitemap7.xml">7</a><a href="https://www.pythonf.cn/public/sitemap/sitemap8.xml">8</a>
# </p>
# </div>
# </div>

# %%
# Tag对象与HTML原生文档中的标签相同，可以直接通过对应名字获取
from bs4 import BeautifulSoup
from urllib import request

url = 'https://pythonf.cn'
headers = {
    
}
req = request.Request(url, headers=headers)
response = request.urlopen(req)
content = response.read()
soup = BeautifulSoup(content, 'html.parser')
tag = soup.title
print(tag)
# Out:
# <title>PythonFree-Python教程</title>

# %%
# 通过Tag对象的name属性，可以获取到标签的名称
tag = soup.title
print(tag.name)
# Out:
# title

# %%
# 一个tag可能包含很多属性，如id、class等，操作tag属性的方式与字典相同。例如网页中导航栏标签 nav
from bs4 import BeautifulSoup
from urllib import request

url = 'https://pythonf.cn'
headers = {
    
}
req = request.Request(url, headers=headers)
response = request.urlopen(req)
content = response.read()
soup = BeautifulSoup(content, 'html.parser')
tag = soup.nav
c = tag['class']
print(c)
# Out:
# ['navbar', 'navbar-default', 'navbar-fixed-top']
